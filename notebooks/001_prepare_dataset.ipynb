# %% [markdown]
# # 001_prepare_dataset

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from nuteval import csv_to_jsonl, load_dataset

# %% [markdown]
# ## Convert csv dataset to jsonl and load saved file

# %%
meals = csv_to_jsonl()
meals_loaded = load_dataset()
